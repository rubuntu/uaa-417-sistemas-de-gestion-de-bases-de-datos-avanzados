# %% [markdown]
# <a href="https://colab.research.google.com/github/rubuntu/uaa-417-sistemas-de-gestion-de-bases-de-datos-avanzados/blob/main/rag_pgvector.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%capture
# Instalar postgresql
# !if [ -f /etc/apt/sources.list.d/pitti-postgresql-$(lsb_release --codename --short).list ]; then rm /etc/apt/sources.list.d/pitti-postgresql-$(lsb_release --codename --short).list; fi
# !echo "deb http://apt.postgresql.org/pub/repos/apt/ $(lsb_release --codename --short)-pgdg main" > /etc/apt/sources.list.d/pgdg.list
# !wget --quiet -O - http://apt.postgresql.org/pub/repos/apt/ACCC4CF8.asc | apt-key add -
# !apt-get update
# !apt-get install pgdg-keyring

# !apt-get install postgresql-17-pgvector postgresql-contrib-17

# %%
# Obtener datos
# !git clone https://github.com/rubuntu/datasets.git
# Out:
# Cloning into 'datasets'...
# remote: Enumerating objects: 1296, done.
# remote: Counting objects: 100% (1296/1296), done.
# remote: Compressing objects: 100% (297/297), done.
# remote: Total 1296 (delta 994), reused 1289 (delta 990), pack-reused 0 (from 0)
# Receiving objects: 100% (1296/1296), 20.52 MiB | 19.64 MiB/s, done.
# Resolving deltas: 100% (994/994), done.

# %%
# Iniciar postgresql
# !service postgresql start
# !sudo -u postgres psql -c "ALTER USER postgres PASSWORD 'postgres';"
# !sudo -u postgres psql -c "CREATE DATABASE ragdb;"

# Crear la extensión pgvector
# !sudo -u postgres psql -d ragdb -c "CREATE EXTENSION IF NOT EXISTS vector;"
#!sudo -u postgres psql -d ragdb -c "\\dx"
# Out:
#  * Starting PostgreSQL 17 database server
#    ...done.
# ALTER ROLE
# CREATE DATABASE
# CREATE EXTENSION

# %%
# %%capture
# Instalar bibliotecas necesarias
# !pip install openai psycopg2-binary sentence-transformers
# Instalar AI Suite
# !pip install aisuite[all]

# %%
import warnings; warnings.filterwarnings('ignore')
import os
import openai
import psycopg2
from psycopg2.extensions import register_adapter, AsIs
from psycopg2.extras import execute_values
from sentence_transformers import SentenceTransformer

# %%
# Configurar modelo para embeddings
#model = SentenceTransformer('all-MiniLM-L6-v2')
model = SentenceTransformer('distiluse-base-multilingual-cased-v1')

# Configuración de la conexión a PostgreSQL
DB_NAME = "ragdb"
DB_USER = "postgres"
DB_PASSWORD = "postgres"
DB_HOST = "localhost"
DB_PORT = "5432"
# Out:
# modules.json:   0%|          | 0.00/341 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/2.47k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/556 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/539M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/452 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/996k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# 2_Dense/config.json:   0%|          | 0.00/114 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.58M [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.58M [00:00<?, ?B/s]

# %%
def connect_to_db():
    """Establecer conexión con la base de datos PostgreSQL."""
    return psycopg2.connect(
        dbname=DB_NAME, user=DB_USER, password=DB_PASSWORD, host=DB_HOST, port=DB_PORT
    )

def create_table():
    """Crear tabla para almacenar los embeddings."""
    query = """
    CREATE TABLE IF NOT EXISTS markdown_embeddings (
        id SERIAL PRIMARY KEY,
        file_path TEXT NOT NULL,
        content TEXT NOT NULL,
        embedding VECTOR(512)
    );
    """
    with connect_to_db() as conn:
        with conn.cursor() as cur:
            cur.execute(query)
            conn.commit()

def process_markdown_files(root_dir):
    """Leer archivos Markdown y generar embeddings."""
    data_to_insert = []
    for dirpath, _, filenames in os.walk(root_dir):
        for filename in filenames:
            if filename.endswith('.md'):
                file_path = os.path.join(dirpath, filename)
                with open(file_path, 'r', encoding='utf-8') as file:
                    content = file.read()
                    embedding = model.encode(content).tolist()
                    data_to_insert.append((file_path, content, embedding))
    return data_to_insert

def insert_embeddings(data):
    """Insertar embeddings en la base de datos."""
    query = """
    INSERT INTO markdown_embeddings (file_path, content, embedding)
    VALUES %s
    """
    with connect_to_db() as conn:
        with conn.cursor() as cur:
            execute_values(cur, query, data, template=None)
            conn.commit()

# %%
import warnings; warnings.filterwarnings('ignore')

# Crear tabla si no existe
create_table()

# Procesar archivos Markdown
root_directory = "datasets/www.indufar.com.py/"
embeddings_data = process_markdown_files(root_directory)

# Insertar datos en la base de datos
insert_embeddings(embeddings_data)
print(f"Procesados e insertados {len(embeddings_data)} archivos Markdown en la base de datos.")
# Out:
# Procesados e insertados 123 archivos Markdown en la base de datos.

# %%
# Generar el embedding de la pregunta
question = "Productos para la fiebre de Indufar"
question_embedding = model.encode(question).tolist()

# %%
# Crear la extensión si no existe
def ensure_pgvector_extension():
    with psycopg2.connect(
        dbname=DB_NAME, user=DB_USER, password=DB_PASSWORD, host=DB_HOST, port=DB_PORT
    ) as conn:
        with conn.cursor() as cur:
            cur.execute("CREATE EXTENSION IF NOT EXISTS vector;")
            conn.commit()

# Buscar documentos más cercanos a la pregunta
def find_similar_documents(embedding):
    query = """
        SELECT file_path, content, embedding <-> vector(%s) AS distance
        FROM markdown_embeddings
        ORDER BY distance ASC
        LIMIT 5;
    """
    # Convertir embedding a formato compatible con PostgreSQL
    embedding_str = f"[{','.join(map(str, embedding))}]"

    with psycopg2.connect(
        dbname=DB_NAME, user=DB_USER, password=DB_PASSWORD, host=DB_HOST, port=DB_PORT
    ) as conn:
        with conn.cursor() as cur:
            cur.execute(query, (embedding_str,))
            results = cur.fetchall()
    return results

# %%
# Asegurar la extensión y buscar documentos
ensure_pgvector_extension()  # Crear la extensión si no existe

# Buscar documentos similares
results = find_similar_documents(question_embedding)

# Mostrar resultados
print("Documentos similares a la pregunta:")
texto=""
for result in results:
    file_path, content, distance = result
    print(f"Archivo: {file_path}\nDistancia: {distance}\nContenido: {content[:100]}...\n")
    texto = texto + "\n\n"+ "-"*50 + "\n\n" + content  # Separar documentos
# Out:
# Documentos similares a la pregunta:
# Archivo: datasets/www.indufar.com.py/files/shares/prospectos/400000186.md
# Distancia: 1.0103150280567732
# Contenido: Dermafar
# Loción
# Antipruriginoso - Antialérgico
# Suavizante - Refrescante
# FÓRMULA
# Cada 100 mL contien...
#
# Archivo: datasets/www.indufar.com.py/files/shares/prospectos_/400000559.md
# Distancia: 1.0365767035950177
# Contenido: Z-CAL REUMA CREMA
# Diclofenac  -  Salicilato  de  Metilo
# Via  de  Administración:  Tópica
# Analgésico ...
#
# Archivo: datasets/www.indufar.com.py/files/shares/prospectos_/400000818.md
# Distancia: 1.0372779263819043
# Contenido: Paracetamol 500 mg
# Analgésico y antifebril que no irrita la mucosa gástrica.
# Polvo  Efervescente
# Via...
#
# Archivo: datasets/www.indufar.com.py/files/shares/prospectos/400001415.md
# Distancia: 1.038484111225385
# Contenido: ADEMIR
# Remdesivir  100  mg
# Solución  inyectable  concentrada  para  perfusión
# Via  de  administració...
#
# Archivo: datasets/www.indufar.com.py/files/shares/prospectos_/400000696.md
# Distancia: 1.0406915614746632
# Contenido: Paracetamol - Pseudoefedrina - Clorfeniramina
# Antigripal - Analgésico - Antifebril
# FÓRMULA
# Cada sobr...

# %%
import os # Establecer el tamaño del contexto a 128k (128000 tokens)
os.environ["OLLAMA_NUM_CTX"] = "16384"

# %%
# %%capture
# Instalar pciutils, lshw
# !sudo apt-get install -y pciutils lshw

# Instalar Ollama para Linux
# !curl -fsSL https://ollama.com/install.sh | sh

# Iniciar Ollama
# !nohup ollama serve &
# !sleep 10

# Verificar Ollama
# !ss -ltpn | grep :11434

# Obtener modelo phi3:mini
#!ollama pull phi3:mini

# Obtener modelo phi3:medium
#!ollama pull phi3:medium

# Obtener modelo Llama
# !ollama pull llama3.2

# Obtener modelo phi3:medium-128k
#!ollama pull phi3:medium-128k

# Obtener modelo gemma:7b
# !ollama pull gemma:7b

#Obtener qwen2
# !ollama pull qwen2

# %%
import aisuite as ai
from IPython.display import display, Markdown

client = ai.Client()
messages = [
    {"role": "system", "content": "Eres un asistente útil. Responde la pregunta basándose únicamente en el texto que aparece a continuación."},
    {"role": "user", "content": f"Responde la pregunta como markdown basándose en el siguiente texto:\n\n{texto}\n\nPregunta: {question}\n"},
]

# %%
ollama_tinyllama = "ollama:tinyllama"
ollama_phi3mini = "ollama:phi3:mini"
ollama_phi3medium = "ollama:phi3:medium-128k"
ollama_llama32 = "ollama:llama3.2"
ollama_gemma7b = "ollama:gemma:7b"
ollama_qwen2 = "ollama:qwen2"
response = client.chat.completions.create(model=ollama_qwen2, messages=messages, temperature=0.7)
#print(response.choices[0].message.content)
display(Markdown(response.choices[0].message.content))
# Out:
# Indufar ofrece productos para el alivio de los síntomas de la fiebre, entre ellos:
#
# 1. **Paracetamol - Pseudoefedrina - Clorfeniramina**: Este es un medicamento antigripal que también tiene efectos descongestivos y antialérgicos. Cada sobre de 3 g contiene:
#    - Paracetamol: 500 mg
#    - Pseudoefedrina HCl: 50 mg
#    - Clorfeniramina maleato: 2,5 mg
#
# Para administrar este medicamento a adultos y niños mayores de 12 años, se debe disolver el contenido del sobre en una taza de agua, preferentemente caliente. La dosis máxima de Paracetamol no debe exceder los 4 g al día.
#
# Los posibles efectos adversos incluyen mareos, fatiga, debilidad y somnolencia.
#
# 2. **Medicamento contra la fiebre no especificado**: El texto proporciona una referencia a un medicamento para la fiebre pero la lista de ingredientes y detalles específicos no se ofrecen en este extracto. Puede ser necesario revisar más detalladamente el producto específico en la documentación o página web de Indufar.
#
# Ambos productos están disponibles en cajas que contienen 10 sobres con 3 gramos cada uno, y deben ser guardados fuera del alcance de los niños. Además, se recomienda conservarlo en un lugar seco a temperatura ambiente, entre 25º C y si la variación admitida es entre 15º y 30º C.
#
# Además de su uso y descripción, esta información incluye detalles como la dirección del regente del medicamento (Dr. Humberto Simón - Reg. Nº 535), y las direcciones físicas e informativas de contacto para Indufar, ubicado en Paraguay.

# %%
# Generar el embedding de la pregunta
question = "¿Qué usos tiene el paracetamol y que productos de Indufar lo tienen?"
question_embedding = model.encode(question).tolist()
results = find_similar_documents(question_embedding)

print("Documentos similares a la pregunta:")
texto=""
for result in results:
    file_path, content, distance = result
    print(f"Archivo: {file_path}\nDistancia: {distance}\nContenido: {content[:100]}...\n")
    texto += "\n"+ "-"*50 + "\n" + content  # Separar documentos

messages = [
    {"role": "system", "content": "Eres un asistente útil. Responde la pregunta basándose únicamente en el texto que aparece a continuación."},
    {"role": "user", "content": f"El nombre del medicamento suele ser la primera frase del documento separado por lineas en el texto. Responde la pregunta como markdown basándose en el siguiente texto:\n\n{texto}\n\nPregunta: {question}\n"},
]

response = client.chat.completions.create(model=ollama_llama32, messages=messages, temperature=0.75)
display(Markdown(response.choices[0].message.content))
# Out:
# Documentos similares a la pregunta:
# Archivo: datasets/www.indufar.com.py/files/shares/prospectos_/400000696.md
# Distancia: 0.8924611889390553
# Contenido: Paracetamol - Pseudoefedrina - Clorfeniramina
# Antigripal - Analgésico - Antifebril
# FÓRMULA
# Cada sobr...
#
# Archivo: datasets/www.indufar.com.py/files/shares/prospectos/400001832.md
# Distancia: 0.900394232819253
# Contenido: El  uso  con  deferoxamina,  medicamento  usado  para  el  tratamiento  de  sobrecargas
# orgánicas  ...
#
# Archivo: datasets/www.indufar.com.py/files/shares/prospectos/400001718.md
# Distancia: 0.9104859569436508
# Contenido: Comprimidos  Masticables
# Paracetamol  80  mg
# Antifebril  -  Analgésico
# Vía  administración:  Oral
# FÓ...
#
# Archivo: datasets/www.indufar.com.py/files/shares/prospectos_/400000818.md
# Distancia: 0.9125732614554001
# Contenido: Paracetamol 500 mg
# Analgésico y antifebril que no irrita la mucosa gástrica.
# Polvo  Efervescente
# Via...
#
# Archivo: datasets/www.indufar.com.py/files/shares/prospectos_/400000820.md
# Distancia: 0.9168178404794814
# Contenido: FORTE
# Paracetamol  +  Cafeína
# Polvo  Efervescente
# Analgésico  -  Antipirético
# Vía  de  Administració...
# El paracetamol es un medicamento analgésico, antipirético y antiinflamatorio que se utiliza para aliviar los síntomas de dolor, fiebre y inflamación en various condiciones, como:
#
# * Dolor de cabeza
# * Dolores musculares y articulares
# * Fiebre
# * Enfermedades del sistema respiratorio, como la gripe y el resfriado común
# * Enfermedades del sistema digestivo, como el dolor abdominal
#
# El paracetamol es un componente de varios productos de Indufar, entre ellos:
#
# * "Paracetamol efervescente" en sobres de 7,9 gramos, presentados en una caja que contiene 10 sobres.
# * El producto se recomienda para uso internamente y solo debe ser utilizado bajo la indicación del médico.
#
# Es importante mencionar que el paracetamol puede causar intoxicación si se ingiere en grandes cantidades, por lo que es importante seguir las instrucciones de dosificación y utilizarlo solo bajo la supervisión de un profesional de la salud.
